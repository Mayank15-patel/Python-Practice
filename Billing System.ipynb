# %%
item_1 = input ("Enter item 1: ")
price_1 = float(input ("Enter item 1 price: "))
quantity_1 = int(input("Enter item 1 quantity: "))
item_2 = input ("Enter itm 2: ")
price_2 = float(input ("Enter item 2 price: "))
quantity_2 = int(input("Enter item 2 quantity: "))
item_3 = input ("Enter item 3: ")
price_3 = float(input ("Enter item 3 price: "))
quantity_3 = int(input("Enter item 3 quantity: "))
item_4 = input ("Enter item 4: ")
price_4 = float(input ("Enter item 4 price: "))
quantity_4 = int(input("Enter item 4 quantity: "))
item_5 = input ("Enter item 5: ")
price_5 = float(input ("Enter item 5 price: "))
quantity_5 = int(input("Enter item 5 quantity: "))
print()
print ("      Patel Mart      ")
print ("----------------------")
print (" CIN :- LGHNKFB73YR3  ")
print (" GSTIN :- 26KHDBKSF86Y  ")
print (" FSSAI NO. 123156130351  ")
print ("----------------------")
print ("      Tax Invoice      ")
print ("----------------------")
print ("Particulars  |  Qty  |  Value"  )
print ("----------------------")
print (f"{item_1}  |  {quantity_1} | {price_1}")
print (f"{item_2}  |  {quantity_2} |  {price_2}")
print (f"{item_3}  |  {quantity_3} |  {price_3}")
print (f"{item_4}  |  {quantity_4} |  {price_4}")
print (f"{item_5}  |  {quantity_5} |  {price_5}")
print ("----------------------")

add = price_1 + price_2 + price_3 + price_4 + price_5
total_quantity = quantity_1 + quantity_2 + quantity_3 + quantity_4 + quantity_5
print()
print("Total Quantity : ", total_quantity)
print("Total:", add)
print ("Total amount after GST: ", add+add*0.5)
print ()
print ("----------------------")
print ("Thank You for shopping.")
print ("      Visit Again     ")
# Out:
# Enter item 1:  Sugar1kg
# Enter item 1 price:  42
# Enter item 1 quantity:  1
# Enter itm 2:  Salt2kg
# Enter item 2 price:  56
# Enter item 2 quantity:  2
# Enter item 3:  DairyMilk
# Enter item 3 price:  150
# Enter item 3 quantity:  2
# Enter item 4:  Cup
# Enter item 4 price:  99
# Enter item 4 quantity:  1
# Enter item 5:  Hide&Seek
# Enter item 5 price:  95.56
# Enter item 5 quantity:  1
#       Patel Mart
# ----------------------
#  CIN :- LGHNKFB73YR3
#  GSTIN :- 26KHDBKSF86Y
#  FSSAI NO. 123156130351
# ----------------------
#       Tax Invoice
# ----------------------
# Particulars  |  Qty  |  Value
# ----------------------
# Sugar1kg  |  1 | 42.0
# Salt2kg  |  2 |  56.0
# DairyMilk  |  2 |  150.0
# Cup  |  1 |  99.0
# Hide&Seek  |  1 |  95.56
# ----------------------
#
# Total Quantity :  7
# Total: 442.56
# Total amount after GST:  663.84
#
# ----------------------
# Thank You for shopping.
#       Visit Again

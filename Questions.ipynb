# %%
# 6. Print the below words in each line using a single print function
#    Python
#    is 
#    Fun

print ("Python\nis\nFun")
# Out:
# Python
# is
# Fun

# %%
# 7. Create variables of the following types and print them with their types:
# Integer, Float, String, Boolean, Complex number.

i = 50
f = 50.55
s = "Mayank"
b = True
c = 1+5j
print (f"Variable is {i} and its type is {type(i)}")
print (f"Variable is {f} and its type is {type(f)}")
print (f"Variable is {s} and its type is {type(s)}")
print (f"Variable is {b} and its type is {type(b)}")
print (f"Variable is {c} and its type is {type(c)}")
# Out:
# Variable is 50 and its type is <class 'int'>
# Variable is 50.55 and its type is <class 'float'>
# Variable is Mayank and its type is <class 'str'>
# Variable is True and its type is <class 'bool'>
# Variable is (1+5j) and its type is <class 'complex'>

# %%
# 8. Write a program that checks the type of: x = True, y = None

x= True
y = None
print ("The type of x is", type(x))
print ("The type of y is", type(y))
# Out:
# The type of x is <class 'bool'>
# The type of y is <class 'NoneType'>

# %%
# 9. Predict the output:  print(type(type(5)))

print ("The output is", type(type(5)))
# Out:
# The output is <class 'type'>

# %%
# 10. Store your roll number and percentage, then print them in one line.

roll_no = 45
percentage = 75

print(f"Roll no. is {roll_no} and their percentage is {percentage}%.")
# Out:
# Roll no. is 45 and their percentage is 75%.
